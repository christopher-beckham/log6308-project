# %%
import numpy as np
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
# %matplotlib inline

from pylab import rcParams
rcParams['figure.figsize'] = 18, 14

# %%
dat = np.load("./hybrid_item_c50_transformed.npy")

# %%
dat
# Out:
# array([[  3.65725326,  29.95591054],
#        [  3.51243389, -40.80073155],
#        [ 27.48847928,  23.12768059],
#        ...,
#        [-26.7852079 ,   9.18014542],
#        [ 19.59324024,  19.23957782],
#        [ -8.52493706, -10.25092387]])

# %%
plt.scatter(dat[:,0], dat[:,1], lw=0)
plt.axis("off")
# Out:
# (-60.0, 60.0, -60.0, 60.0)

# %%
dat.shape
# Out:
# (68543, 2)

# %%
# ?bh_sne

# %% [markdown]
# ----

# %%
dat2 = np.load("./test3.code.npy")

# %%
dat2
# Out:
# array([[  0.        ,   0.        ,  24.96246727, ...,  84.59532414,
#           0.        ,  18.00387717],
#        [  0.        ,   0.        ,  15.21269087, ...,  52.69406954,
#           0.        ,  11.18409217],
#        [  0.        ,   0.        ,  20.35295376, ...,  69.57357652,
#           0.        ,  14.74327808],
#        ...,
#        [  0.        ,   0.        ,  20.45096688, ...,  70.01396682,
#           0.        ,  15.19402514],
#        [  0.        ,   0.        ,  19.43845859, ...,  67.18013766,
#           0.        ,  14.24967416],
#        [  0.        ,   0.        ,  16.54159216, ...,  56.48727502,
#           0.        ,  12.03551934]])

# %%
plt.imshow(dat2[0:200,:], cmap="gray")

# %%
dat2
# Out:
# array([[-2.31330752, -3.06682181, -3.23553967, ..., -3.50678587,
#         -3.50833106, -3.5074234 ],
#        [-2.31330752, -3.06682181, -3.23553967, ..., -3.50678587,
#         -3.50833106, -3.5074234 ],
#        [-2.31330752, -3.06682181, -3.23553967, ..., -3.50678587,
#         -3.50833106, -3.5074234 ],
#        ...,
#        [-2.31330729, -3.06682181, -3.23553967, ..., -3.50678587,
#         -3.50833106, -3.5074234 ],
#        [-2.31330752, -3.06682181, -3.23553967, ..., -3.50678587,
#         -3.50833106, -3.5074234 ],
#        [-2.31330729, -3.06682181, -3.23553967, ..., -3.50678587,
#         -3.50833106, -3.5074234 ]], dtype=float32)

# %%
tmp = np.random.normal(0, 5, size=(100,500))
plt.figure(1)
plt.imshow(tmp)

tmp = np.random.normal(0, 0.0001, size=(50,250))
plt.figure(2)
plt.imshow(tmp)

plt.show()

plt.savefig("test.png")

# %%
from IPython.display import Image
Image("test.png")
